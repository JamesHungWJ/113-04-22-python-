# %% [markdown]
# 在lesson10_homework.ipynb

# %% [markdown]
# - CSV檔  -- 簡單的表格資料 參考aqx_p_488.csv
# - JSON檔 -- 複雜的資料結構 參考aqx_P_488.json
#
# ![image-2.png](attachment:image-2.png)
#
# - JSON形式
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
