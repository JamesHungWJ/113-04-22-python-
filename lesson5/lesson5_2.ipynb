# %% [markdown]
# ## try...except練習

# %%
try:
    score:int|float = int(input("請輸入學生分數(最高300分)"))
    if score<=300:
        is_add:str = input("學生是否符合加分條件(y,n)")
        if is_add == "y":
            score *= 1.05
            if score > 300:
                score = 300
        print(f"學生的總分是{int(score)}")
    else:
        print("輸入的分數不可以超過300分")
except Exception as e:
    print(f"發生錯誤{e}")

# %% [markdown]
# ## 課業練習
#
# 輸入：
# - 請輸入姓名：
# - 請輸入身高(cm)：
# - 請輸入體重(kg)：
#
# 輸出：
# - xxx，您的BMI：
#
# 錯誤：
# - 格式錯誤：XXXXX
#
# ![image.png](attachment:image.png)

# %%
try:
    name=input("請輸入您的姓名：")
    hieght=eval(input("請輸入您的身高(cm)"))
    wieght=eval(input("請輸入您的體重"))
    BMI=round(wieght/((hieght/100)**2),ndigits=2)

    print(f"{name},您的身高為{hieght}，您的體重為{wieght}，經計算BMI為{BMI}")
except Exception as e:
    print(f"發生錯誤{e}")
# Out:
# 15,您的身高為1567，您的體重為54，經計算BMI為0.22

# %% [markdown]
# - 更新 pip，在終端機輸入：install --upgrade pip
# - 增加套件，在終端機輸入：pip install --upgrade pip
